# %%
from pathlib import Path

import pandas as pd
import numpy as np

# %%
project_path = Path.cwd()
data_path_unprocessed = project_path / 'data' / '01_reduced'
data_path_processed = project_path / 'data' / '02_processed'
data_path_cleaned = project_path / 'data' / '03_cleaned'

# %%
df_in = pd.read_parquet(data_path_unprocessed / 'inputs.pqt')
df_out = pd.read_parquet(data_path_unprocessed / 'targets.pqt')

# %% [markdown]
# ### Cleaning Inputs

# %%
df_in.head()
# Out:
#      id      lat    lon  etopo2  oisst     es411     es443     es489  \
# 0  1565  38.4279 -76.61     0.0   3.70  107.9060  121.1870  137.2660
# 1  1566  38.3680 -76.50     0.0   3.70  113.8600  128.0530  145.1480
# 2  1567  38.3074 -76.44     1.0   3.70  114.3500  128.0550  146.0600
# 3  1568  38.6367 -76.32     3.0   3.70   35.0441   38.1511   42.1373
# 4  1559  38.3047 -76.44     1.0  22.03   61.8732   67.0335   72.2731
#
#       es510     es555     es670     lw411     lw443     lw489     lw510  \
# 0  134.0370  130.9470  112.9250  0.129962  0.204331  0.452029  0.541019
# 1  140.9650  138.3500  118.5550  0.120886  0.177228  0.315395  0.352306
# 2  142.7250  140.1980  119.9780  0.111049  0.151807  0.269218  0.326515
# 3   40.5485   39.2907   31.7094  0.051578  0.066430  0.121242  0.148580
# 4   69.6545   77.1321   50.0766  0.056001  0.068530  0.108838  0.132581
#
#       lw555     lw670
# 0  0.979378  0.391235
# 1  0.574440  0.200936
# 2  0.595226  0.193438
# 3  0.274316  0.102543
# 4  0.216023  0.089663

# %%
λ = [411, 443, 489, 510, 555, 670]
for λi in λ:
    df_in[f'Rrs{λi}'] = df_in[f'lw{λi}'] / df_in[f'es{λi}']

# %%
df_in.head()
# Out:
#      id      lat    lon  etopo2  oisst     es411     es443     es489  \
# 0  1565  38.4279 -76.61     0.0   3.70  107.9060  121.1870  137.2660
# 1  1566  38.3680 -76.50     0.0   3.70  113.8600  128.0530  145.1480
# 2  1567  38.3074 -76.44     1.0   3.70  114.3500  128.0550  146.0600
# 3  1568  38.6367 -76.32     3.0   3.70   35.0441   38.1511   42.1373
# 4  1559  38.3047 -76.44     1.0  22.03   61.8732   67.0335   72.2731
#
#       es510     es555  ...     lw489     lw510     lw555     lw670    Rrs411  \
# 0  134.0370  130.9470  ...  0.452029  0.541019  0.979378  0.391235  0.001204
# 1  140.9650  138.3500  ...  0.315395  0.352306  0.574440  0.200936  0.001062
# 2  142.7250  140.1980  ...  0.269218  0.326515  0.595226  0.193438  0.000971
# 3   40.5485   39.2907  ...  0.121242  0.148580  0.274316  0.102543  0.001472
# 4   69.6545   77.1321  ...  0.108838  0.132581  0.216023  0.089663  0.000905
#
#      Rrs443    Rrs489    Rrs510    Rrs555    Rrs670
# 0  0.001686  0.003293  0.004036  0.007479  0.003465
# 1  0.001384  0.002173  0.002499  0.004152  0.001695
# 2  0.001185  0.001843  0.002288  0.004246  0.001612
# 3  0.001741  0.002877  0.003664  0.006982  0.003234
# 4  0.001022  0.001506  0.001903  0.002801  0.001791
#
# [5 rows x 23 columns]

# %%
df_in.to_parquet(data_path_processed / 'df_in.pqt')

# %%
df_in.filter(regex='(id)|(Rrs[0-9]+)', axis=1).to_parquet(data_path_cleaned/'df_in.pqt')

# %% [markdown]
# ### Cleaning Output

# %%
df_out
# Out:
#         id       chl  chl_a    ad411    ad443    ad489    ad510    ap411  \
# 0     1565  38.19000    NaN  0.78272  0.47467  0.23128  0.16657  1.52149
# 1     1566  35.01000    NaN      NaN      NaN      NaN      NaN      NaN
# 2     1567  26.91000    NaN  0.27165  0.14016  0.05413  0.03506  0.77966
# 3     1568  47.96000    NaN      NaN      NaN      NaN      NaN      NaN
# 4     1559  23.55000    NaN  0.76505  0.43701  0.19538  0.13529  1.62324
# ...    ...       ...    ...      ...      ...      ...      ...      ...
# 4454  6901   4.62784    NaN  0.03151  0.02175  0.01276  0.01000  0.22345
# 4455  6902   2.95997    NaN      NaN      NaN      NaN      NaN      NaN
# 4456  6914   0.95114    NaN      NaN      NaN      NaN      NaN      NaN
# 4457  6903   4.54228    NaN  0.01395  0.01010  0.00636  0.00514  0.18583
# 4458  6915   5.80693    NaN  0.01828  0.01281  0.00768  0.00608  0.24630
#
#         ap443    ap489    ap510    ap555    ap670
# 0     1.38905  0.81987  0.64517  0.24726  0.63165
# 1         NaN      NaN      NaN      NaN      NaN
# 2     0.73214  0.42119  0.33765  0.14978  0.40562
# 3         NaN      NaN      NaN      NaN      NaN
# 4     1.54082  0.96391  0.72949  0.18209  0.46114
# ...       ...      ...      ...      ...      ...
# 4454  0.20338  0.13320  0.09238  0.03786  0.06421
# 4455      NaN      NaN      NaN      NaN      NaN
# 4456      NaN      NaN      NaN      NaN      NaN
# 4457  0.17516  0.11804  0.08267  0.03175  0.05858
# 4458  0.22272  0.15457  0.11426  0.04968  0.07633
#
# [4459 rows x 13 columns]

# %%
df_out[['chl', 'chl_a']]
# Out:
#            chl  chl_a
# 0     38.19000    NaN
# 1     35.01000    NaN
# 2     26.91000    NaN
# 3     47.96000    NaN
# 4     23.55000    NaN
# ...        ...    ...
# 4454   4.62784    NaN
# 4455   2.95997    NaN
# 4456   0.95114    NaN
# 4457   4.54228    NaN
# 4458   5.80693    NaN
#
# [4459 rows x 2 columns]

# %%
df_chl = df_out[['id', 'chl', 'chl_a']].copy()

# %%
def create_chl_and_flag(df):
    """
    Creates 'chl' and 'hplc_flag' columns based on the rules provided.

    Args:
        df (pd.DataFrame): Input DataFrame with 'chl' and 'chl_a' columns.

    Returns:
        pd.DataFrame: DataFrame with new 'chl' and 'hplc_flag' columns.
    """
    new_chl = np.select(
        [
            df['chl_a'].notna(),
            df['chl'].notna() & df['chl_a'].isna(),
            df['chl'].isna() & df['chl_a'].isna()
        ],
        [
            df['chl_a'],
            df['chl'],
            np.nan
        ],
        default=np.nan  # Should not be reached based on the conditions
    )

    hplc_flag = np.select(
        [
            df['chl_a'].notna(),
            df['chl'].notna() & df['chl_a'].isna(),
            df['chl'].isna() & df['chl_a'].isna()
        ],
        ['1', '0', '-1'],
        default='-1' # Should not be reached based on the conditions
    )

    new_df = df.copy()
    new_df['chl'] = new_chl
    new_df['hplc_flag'] = hplc_flag
    return new_df[['chl', 'hplc_flag']]

# %%
new_df_chl = create_chl_and_flag(df_chl)

# %%
df_chl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4459 non-null   int64
#  1   chl     3392 non-null   float64
#  2   chl_a   1381 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 104.6 KB

# %%
df_chl.loc[df_chl['chl'].isna() & df_chl['chl_a'].isna()]
# Out:
#         id  chl  chl_a
# 9     1574  NaN    NaN
# 19    1601  NaN    NaN
# 20    1604  NaN    NaN
# 37    1625  NaN    NaN
# 39    1627  NaN    NaN
# ...    ...  ...    ...
# 4369  7777  NaN    NaN
# 4373  7785  NaN    NaN
# 4374  7786  NaN    NaN
# 4375  7787  NaN    NaN
# 4430  6886  NaN    NaN
#
# [332 rows x 3 columns]

# %%
df_chl.loc[9]
# Out:
# id       1574.0
# chl         NaN
# chl_a       NaN
# Name: 9, dtype: float64

# %%
df_chl.dropna(axis=1, how='all')
# Out:
#         id       chl  chl_a
# 0     1565  38.19000    NaN
# 1     1566  35.01000    NaN
# 2     1567  26.91000    NaN
# 3     1568  47.96000    NaN
# 4     1559  23.55000    NaN
# ...    ...       ...    ...
# 4454  6901   4.62784    NaN
# 4455  6902   2.95997    NaN
# 4456  6914   0.95114    NaN
# 4457  6903   4.54228    NaN
# 4458  6915   5.80693    NaN
#
# [4459 rows x 3 columns]

# %%
new_df_chl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   chl        4127 non-null   float64
#  1   hplc_flag  4459 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 69.8+ KB

# %%
new_df_chl.to_parquet(data_path_cleaned / 'df_out_chl.pqt')
